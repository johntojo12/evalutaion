# %% [markdown]
# # HR Analytics Project
# Understanding the Attrition in HR Problem Statement: Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
# HR Analytics
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# Attrition in HR
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
# Attrition affecting Companies
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.
#
# #### features:
#
# Age - refers how old the person is
#
# BusinessTravel - takes any of 3 values: 1 Travel_Rarely 2 Travel_Frequently 3 Non-Travel
#
# DailyRate - daily wage of an employee
#
# Department - the department in which the employee is working in
#
# DistanceFromHome- the distance the employee has to travel from his house to office
#
# Education - take the following values: 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'
#
# EducationField: the field the person has done his eductaion
#
# EnvironmentSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# JobInvolvement 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# JobSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# PerformanceRating 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'
#
# RelationshipSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# WorkLifeBalance 1 'Bad' 2 'Good' 3 'Better' 4 'Best'
#
# Gender - takes two values Male or Female
#
# HourlyRate - the rate at which the employee is paid by the hour
#
# JobRole - the designation of the employee
#
# MaritalStatus - married single or divorced
#
# MonthlyIncome - the income employee get at the end of the month
#
# MonthlyRate - the rate the employee get per month
#
# NumCompaniesWorked - no. of companies the employee has worked before joining the company
#
# OverTime - if the employee prefers to work over time
#
# PercentSalaryHike - the percentage of salary hike the employee recieves
#
# StandardHours - the time an employee is expected to work a week
#
# StockOptionLevel - the option the employee has opted for
#
# TotalWorkingYears - the total working experince of an employee
#
# TrainingTimesLastYear - the no. of time the employee has recieved training
#
# YearsAtCompany -  the no. of years the employee has been working for the company
#
# YearsInCurrentRole - the no. of years the employee has been in the current role
#
# YearsSinceLastPromotion - the no. of years the employee has been in the same role after getting promoted
#
# YearsWithCurrManager - the no. of years the employee has been working with their manager
#
#
# #### target
#
# Attrition - yes or no

# %%
#importing necessary library
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
#reading csv and storing it in df
#using double slash because of unicode error
df=pd.read_csv("C:\\Users\\JOHN TOJO\\Desktop\\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# #### check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  no duplicates present

# %% [markdown]
# #### checking nulls

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# no null value exists

# %% [markdown]
# #### checking datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# - 1470 rows and 35 columns for the given dataset, attrition as the target
# - attrition is an object data type which takes yes or no hence classification problem
# - there are object and numerical datatypes

# %% [markdown]
# #### Checking for unique values in each columns

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# - EmployeeNumber all datas are unique assuming that its for identifying employee hence can be dropped
# - EmployeeCount  has only 1 unique data so it means that its the same for the entire column hence can be dropped
# - Over18 from the data it can be seen that min age is 18 and also the unique data present in this column is 1 hence can be dropped
# - StandardHours has only 1 unique data that is 80 hours hence can be dropped

# %% [markdown]
# #### deleting the columns EmployeeNumber, EmployeeCount,Over18 and StandardHours

# %%
df.drop(['EmployeeNumber','EmployeeCount','Over18','StandardHours'],inplace=True,axis=1)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# #### seperating numerical and categorical data type

# %%
numericalCol=df.select_dtypes(include=np.number).columns
print("The numerical columns are:",numericalCol)
print('\n')
objectColumns=df.select_dtypes(include=np.object).columns
print("The categorical columns are:",objectColumns)
# Out:
# The numerical columns are: Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')
#
#
# The categorical columns are: Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'OverTime'],
#       dtype='object')

# %% [markdown]
# #### diving numerical columns into two categories discrete and continuous

# %%
discretecols=[]
continuecols=[]

for column in numericalCol:
     if df[column].nunique()>50:
        continuecols.append(column)
     
     else:
        discretecols.append(column)
        
print("The discrete columns are:",discretecols)
print('\n')
print("The continuous columns are:",continuecols)
# Out:
# The discrete columns are: ['Age', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
#
# The continuous columns are: ['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate']

# %% [markdown]
# #### checking how the data is defined statistically for numerical continuous datas and visualising

# %%
df[continuecols].describe().T
# Out:
#                 count          mean          std     min     25%      50%  \
# DailyRate      1470.0    802.485714   403.509100   102.0   465.0    802.0
# HourlyRate     1470.0     65.891156    20.329428    30.0    48.0     66.0
# MonthlyIncome  1470.0   6502.931293  4707.956783  1009.0  2911.0   4919.0
# MonthlyRate    1470.0  14313.103401  7117.786044  2094.0  8047.0  14235.5
#
#                     75%      max
# DailyRate       1157.00   1499.0
# HourlyRate        83.75    100.0
# MonthlyIncome   8379.00  19999.0
# MonthlyRate    20461.50  26999.0

# %% [markdown]
#  - the mean to std ratio is very small in all the cases
#  - the quantile difference is not uniform in all cases

# %%
# plotting distribution graph 
j=0
plt.figure(figsize=(10,10))
for column in df[continuecols]:
    plt.subplot(6,3,j+1)
    sns.distplot(df[column])
    plt.xlabel(column,fontsize=12)
    j+=1
plt.tight_layout()

# %% [markdown]
# - DailyRate
#     - somewhat unifromly distributed
#     - some amount of skewness present
#     - has values in the range 150-1500
#
#
# - HourlyRate
#     - somewhat unifromly distributed
#     - some amount of skewness present
#     - has values in the range 30-100
#
#
# - MonthlyIncome
#     - not uniformly distributed
#     - positively skewd
#     - presence of outliers
#     - value in range 1000-10000
#
#
# - MonthlyRate
#     - somewhat unifromly distributed
#     - some amount of skewness present
#     - has values in the range 2100-27000

# %%
types=df.groupby('Attrition')[['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate']].mean()
print(types)
ax=types.plot(y=['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate'],kind='bar')
plt.ylabel(ylabel='Attrition')
plt.xlabel(xlabel=[['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate']])
plt.show()
# Out:
#             DailyRate  HourlyRate  MonthlyIncome   MonthlyRate
# Attrition
# No         812.504461   65.952149    6832.739659  14265.779400
# Yes        750.362869   65.573840    4787.092827  14559.308017

# %% [markdown]
# - from this most of those attritions occur when their income is less compared to others

# %% [markdown]
# #### checking how the data is defined statistically for numerical discrete datas and visualising

# %%
df[discretecols].describe().T
# Out:
#                            count       mean       std   min   25%   50%   75%  \
# Age                       1470.0  36.923810  9.135373  18.0  30.0  36.0  43.0
# DistanceFromHome          1470.0   9.192517  8.106864   1.0   2.0   7.0  14.0
# Education                 1470.0   2.912925  1.024165   1.0   2.0   3.0   4.0
# EnvironmentSatisfaction   1470.0   2.721769  1.093082   1.0   2.0   3.0   4.0
# JobInvolvement            1470.0   2.729932  0.711561   1.0   2.0   3.0   3.0
# JobLevel                  1470.0   2.063946  1.106940   1.0   1.0   2.0   3.0
# JobSatisfaction           1470.0   2.728571  1.102846   1.0   2.0   3.0   4.0
# NumCompaniesWorked        1470.0   2.693197  2.498009   0.0   1.0   2.0   4.0
# PercentSalaryHike         1470.0  15.209524  3.659938  11.0  12.0  14.0  18.0
# PerformanceRating         1470.0   3.153741  0.360824   3.0   3.0   3.0   3.0
# RelationshipSatisfaction  1470.0   2.712245  1.081209   1.0   2.0   3.0   4.0
# ...

# %%
# plotting countplot graph 
j=0
plt.figure(figsize=(15,25))
for column in df[discretecols]:
    plt.subplot(10,2,j+1)
    sns.countplot(df[column],hue=df['Attrition'])
    plt.xlabel(column,fontsize=12)
    j+=1
plt.tight_layout()

# %% [markdown]
# - Age
#     - most of the employees are around 28-38
#     - attrition rate is higher for 26-32
#
#
# -  DistanceFromHome
#     - most of the employess live far away from the company
#     - around 400 employees live close to the company that is within 1 to 2
#
#
# - Education
#     - most of employees have lvl 3 education followed by lvl 4
#     - most of employees wth lvl 3 educaion has hgh attrition rate
#
#
# - EnvironmentSatisfaction
#     - most of employees are kind of satisfied with the environment
#     - most of employee has given a rating of 3 followed by rating of 4
#     - employees who have given rating 1 has high chance of attrition
#
#
# -  JobInvolvement
#     - most of employees are involved with their job as the rating given to most of them is 3
#     - very few employee are highly involved with their job as they have a rating of 4 that is around 120 employee
#     - those in job involvement 1 has chance for attrition
#
#
# -  JobLevel
#     - most of the employees are employeed at lvl1 and lvl2
#     - employees in job lvl1 has higher attrition when compared to others
#
#
# -  JobSatisfaction
#     - most of employees are satisfied with their jobs
#     - most of employees have given a rating of 4 followed by 3
#     - employees those who have given rating 1 has chance of attrition
#
#
# -   NumCompaniesWorked
#     - around 500 employees have worked in a company before joining this company
#     - around 770 employees have worked in more than one company before joining this company
#
#
# - PercentSalaryHike
#     - most of the employees get hike in the range 11-14%
#     - employees who recieve hike in 11-13% has chance of attrition
#
#
# - PerformanceRating
#     - most of the employees have a performance rating of 3 implies that employee perform the job assigned very well
#     - employees with rating 3 has chance for attrition
#
#
# - RelationshipSatisfaction
#     - most of employees gave rating of 3 then folowed by 4, indicating employee has high relationship satisfaction
#     - attrition rate is same for all ratings
#     - attrition is higher for those with lvl1 relationship satisfaction
#
#
# - StockOptionLevel
#     - most of employees have opted for no stock option and few have opted for lvl 1 stock option and very few have opted for lvl2 and lvl3
#     - those with lvl0 has the highest attrition
#
#
# - TotalWorkingYears
#     - the company has large no. of employees with total working years at 10
#     - there is accumulation of employees with total working years in the range 5 to 9
#     - employees with 1 totalworking year has attrition rate more compared to other
#
#
# - TrainingTimesLastYear
#     - most of the employees had 2 training followed by 3 training the previous year
#     - employees with 0 and 1 trainings have higher attrition
#
#
# - WorkLifeBalance
#     - most of the employees have said that there is good work life balance as they have given a rating of 3
#     - attrition is higher for employees who opted for rating 1
#
#
# - YearsAtCompany
#     - there is large no of employees who have worked for 5 years
#     - most of the employees stay in the company for 1-9 years as it can be seen that after 10 the no. of employees is very less could be because employees are not getting promoted or not getting hike or not getting a grow in their career
#     - employees who have worked for less than one year has the highest attrition rate
#
#
# - YearsInCurrentRole
#     - there is large no. of employees who are in the current role for past 2 years followed by 7 years
#     - there is large no. of  employees who are in the current role for past 0 years this could be either they got promoted or were hired recently by the company
#     - employees who have worked for 1 year in cuurent role has high chance of attrition
#
#
# - YearsSinceLastPromotion
#     - most of the employees are getting promoted because 0 has the highest value followed by 1 year
#     - there are many employees who have not gotten promoted for the past 7-15 years they could be those who are in high positions
#     - employees who have not gotten promoted in 2-15 years have higher chance of attrition
#
#
# - YearsWithCurrManager
#     - there are many employees who have started working with current manager
#     - there are many cases where employees have worked with current manager  for 2 years and for 7 years
#     - employees who have worked for 1 year, 5-6 years, 10-17 years have high chance of attrition

# %% [markdown]
# #### checking how the data is defined statistically for categorical datas`and visualising

# %%
df[objectColumns].describe(include=['O'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus OverTime
# count              1470          1470     1470
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                326           673     1054

# %%
# plotting countplot graph 
j=0
plt.figure(figsize=(15,25))
for column in df[objectColumns]:
    plt.subplot(10,2,j+1)
    sns.countplot(df[column], hue=df['Attrition'])
    plt.xlabel(column,fontsize=12)
    j+=1
plt.tight_layout()

# %% [markdown]
# - Attrition
#     - No dominates yes
#     - therefore imbalanced dataset
#
#
# - BusinessTravel
#     - most of the employees travel rarely
#     - employees who travel frequently has higher chance of attrition
#
#
# - Department
#     - most of the employees are in R&D followed by sales
#     - HR dept has high cahcne of attrition
#
#
# - EducationField
#     - most of the employees have education in life science followed by medical field
#     - highest in HR, other followed by technical and sales
#
#
# - Gender
#     - most of the employees are male
#     - both have similar attrition rate
#
#
# - JobRole
#     - most of the employees are Sales Executive, followed by Research Scientist
#     - HR has highest attrition rate
#
#
# - MaritalStatus
#     - most of the employees are married
#     - those who are single has the highest attrition rate
#
#
# - OverTime
#     - most of the employees prefer not to work over time
#     - those who work over time has higher attrition rate

# %% [markdown]
# #### check skewness

# %%
df.skew()[continuecols].sort_values()
# Out:
# HourlyRate      -0.032311
# DailyRate       -0.003519
# MonthlyRate      0.018578
# MonthlyIncome    1.369817
# dtype: float64

# %% [markdown]
# skew is not within limits for monthlyIncome

# %% [markdown]
# #### using power transform to transform

# %%
#using power transform to transform and normalize the dataset and storing it in A and copying it to df
from sklearn.preprocessing import power_transform
B=df[continuecols].copy()
A=power_transform(B)
A=pd.DataFrame(A,columns=B.columns)
df[B.columns]=A.copy()
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely   0.759289                   Sales
# 1      49        No  Travel_Frequently  -1.334597  Research & Development
# 2      37       Yes      Travel_Rarely   1.340365  Research & Development
# 3      33        No  Travel_Frequently   1.379936  Research & Development
# 4      27        No      Travel_Rarely  -0.453941  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently   0.264672  Research & Development
# 1466   39        No      Travel_Rarely  -0.397219  Research & Development
# 1467   27        No      Travel_Rarely  -1.751713  Research & Development
# 1468   49        No  Travel_Frequently   0.583235                   Sales
# 1469   34        No      Travel_Rarely  -0.358845  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
df.skew()[continuecols].sort_values()
# Out:
# DailyRate       -0.196160
# MonthlyRate     -0.184087
# HourlyRate      -0.106461
# MonthlyIncome    0.032831
# dtype: float64

# %% [markdown]
# skew is within limits

# %% [markdown]
# #### Encoding

# %%
# tranform Attrition and Overtime into 0 for No and 1 for Yes
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})
df['OverTime'] = df['OverTime'].map({'Yes': 1, 'No': 0})

# %%
k=[ 'BusinessTravel', 'Department', 'EducationField', 'Gender','JobRole', 'MaritalStatus']

# %%
# using ordinal encoding for other object data types
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in k:
    if df[i].dtypes=='object':
        df[i]=oe.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1             2.0   0.759289         2.0                 1
# 1      49          0             1.0  -1.334597         1.0                 8
# 2      37          1             2.0   1.340365         1.0                 2
# 3      33          0             1.0   1.379936         1.0                 3
# 4      27          0             2.0  -0.453941         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0             1.0   0.264672         1.0                23
# 1466   39          0             2.0  -0.397219         1.0                 6
# 1467   27          0             2.0  -1.751713         1.0                 4
# 1468   49          0             1.0   0.583235         2.0                 2
# 1469   34          0             2.0  -0.358845         1.0                 8
#
# ...

# %% [markdown]
# #### Check for balanced or imablanced data

# %%
#used to visualize Outlet_Establishment_Year
plt.figure(figsize=(5,5))
sns.countplot(df['Attrition'])
plt.xlabel("Attrition",fontsize=12)
print(df["Attrition"].value_counts())
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# The data is imbalaned ratio of 1 to 0 is 0.19 ideal it should be around 0.75

# %% [markdown]
# #### SMOTE to balance the dataset

# %%
import six
import joblib
import sys
sys.modules['sklearn.externals.six']=six
sys.modules['sklearn.externals.joblib']=joblib
from imblearn.over_sampling import SMOTE

# %%
X=df.drop(columns=["Attrition"])
Y=df[["Attrition"]]

# %%
# by using smote we are adding data to (Yes) 1 such that the ratio between 1 to 0 becomes 0.75
ove_sm=SMOTE(0.75)
X_s,Y_s=ove_sm.fit_resample(X,Y)
X_s
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41        2.000000   0.759289    2.000000                 1          2
# 1      49        1.000000  -1.334597    1.000000                 8          1
# 2      37        2.000000   1.340365    1.000000                 2          2
# 3      33        1.000000   1.379936    1.000000                 3          4
# 4      27        2.000000  -0.453941    1.000000                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 2152   29        2.000000   0.413321    1.000000                 3          3
# 2153   39        2.000000  -0.577061    1.862559                22          2
# 2154   29        2.000000  -0.154572    1.947459                 1          3
# 2155   51        2.000000   0.484901    2.000000                 5          2
# 2156   23        1.904801   1.349540    2.000000                 1          1
#
# ...

# %%
# storing it back to df
df=pd.concat([X_s,Y_s],axis=1)
df
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41        2.000000   0.759289    2.000000                 1          2
# 1      49        1.000000  -1.334597    1.000000                 8          1
# 2      37        2.000000   1.340365    1.000000                 2          2
# 3      33        1.000000   1.379936    1.000000                 3          4
# 4      27        2.000000  -0.453941    1.000000                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 2152   29        2.000000   0.413321    1.000000                 3          3
# 2153   39        2.000000  -0.577061    1.862559                22          2
# 2154   29        2.000000  -0.154572    1.947459                 1          3
# 2155   51        2.000000   0.484901    2.000000                 5          2
# 2156   23        1.904801   1.349540    2.000000                 1          1
#
# ...

# %%
#used to visualize Outlet_Establishment_Year
plt.figure(figsize=(5,5))
sns.countplot(df['Attrition'])
plt.xlabel("Attrition",fontsize=12)
print(df["Attrition"].value_counts())
# Out:
# 0    1233
# 1     924
# Name: Attrition, dtype: int64

# %% [markdown]
# the data is balaned ratio of 1 to 0 is approx 0.75

# %% [markdown]
# #### checking correlation

# %%
df.corr()["Attrition"].sort_values()
# Out:
# StockOptionLevel           -0.316609
# JobInvolvement             -0.309758
# JobLevel                   -0.286262
# WorkLifeBalance            -0.266692
# JobSatisfaction            -0.258537
# MonthlyIncome              -0.254054
# EnvironmentSatisfaction    -0.232965
# TotalWorkingYears          -0.231901
# YearsInCurrentRole         -0.227877
# Age                        -0.215822
# TrainingTimesLastYear      -0.211925
# YearsWithCurrManager       -0.206621
# RelationshipSatisfaction   -0.185799
# YearsAtCompany             -0.175372
# Education                  -0.160422
# PerformanceRating          -0.123588
# PercentSalaryHike          -0.087603
# YearsSinceLastPromotion    -0.055581
# DailyRate                  -0.052565
# HourlyRate                 -0.009534
# NumCompaniesWorked          0.008700
# MonthlyRate                 0.024801
# BusinessTravel              0.029846
# EducationField              0.043617
# Gender                      0.055216
# ...

# %% [markdown]
# almost all features have very little correlation with the target

# %%
#plotting heatmap to see the correlation 
# visualization of correlation relationships
plt.figure(figsize=(15, 10))
mask = np.triu(df.corr())
sns.heatmap(df.corr(),cmap="YlGnBu",annot = True, fmt = '.2f',mask = mask)
plt.tight_layout()

# %% [markdown]
# #### Checking for multicollinearity by using vif

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
t=df.drop('Attrition',axis=1)
d=sc.fit_transform(df)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(d, i)for i in range(len(t.columns))]
vif['features']=t.columns
vif.sort_values(by='vif',ascending=False)
# Out:
#          vif                  features
# 11  5.694167                  JobLevel
# 23  5.212459         TotalWorkingYears
# 26  5.147541            YearsAtCompany
# 15  5.049458             MonthlyIncome
# 27  3.227905        YearsInCurrentRole
# 29  3.107159      YearsWithCurrManager
# 3   2.229926                Department
# 0   2.196542                       Age
# 12  2.153411                   JobRole
# 20  2.135414         PerformanceRating
# 19  2.131107         PercentSalaryHike
# 28  1.887678   YearsSinceLastPromotion
# 22  1.881922          StockOptionLevel
# 14  1.843032             MaritalStatus
# 17  1.326276        NumCompaniesWorked
# 10  1.133640            JobInvolvement
# 25  1.127428           WorkLifeBalance
# 13  1.114466           JobSatisfaction
# 7   1.112361   EnvironmentSatisfaction
# 5   1.107590                 Education
# 21  1.082246  RelationshipSatisfaction
# 18  1.080999                  OverTime
# 24  1.076380     TrainingTimesLastYear
# ...

# %% [markdown]
# vif is within limits less than 10

# %% [markdown]
# #### Outliers check

# %%
# visualizing
df.plot(kind='box',subplots=True, layout=(7,5),figsize=(25,25))
# Out:
# Age                            AxesSubplot(0.125,0.787927;0.133621x0.0920732)
# BusinessTravel              AxesSubplot(0.285345,0.787927;0.133621x0.0920732)
# DailyRate                    AxesSubplot(0.44569,0.787927;0.133621x0.0920732)
# Department                  AxesSubplot(0.606034,0.787927;0.133621x0.0920732)
# DistanceFromHome            AxesSubplot(0.766379,0.787927;0.133621x0.0920732)
# Education                      AxesSubplot(0.125,0.677439;0.133621x0.0920732)
# EducationField              AxesSubplot(0.285345,0.677439;0.133621x0.0920732)
# EnvironmentSatisfaction      AxesSubplot(0.44569,0.677439;0.133621x0.0920732)
# Gender                      AxesSubplot(0.606034,0.677439;0.133621x0.0920732)
# HourlyRate                  AxesSubplot(0.766379,0.677439;0.133621x0.0920732)
# JobInvolvement                 AxesSubplot(0.125,0.566951;0.133621x0.0920732)
# JobLevel                    AxesSubplot(0.285345,0.566951;0.133621x0.0920732)
# ...

# %% [markdown]
# #### using z score for treating

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
df_x=df[(z<3).all(axis=1)]
data_loss=((df.shape[0]-df_x.shape[0])/df.shape[0])*100
print("data loss ", data_loss, " %")
# Out:
# data loss  5.4242002781641165  %

# %%
# visualizing
df_x.plot(kind='box',subplots=True, layout=(7,5),figsize=(25,25))
# Out:
# Age                            AxesSubplot(0.125,0.787927;0.133621x0.0920732)
# BusinessTravel              AxesSubplot(0.285345,0.787927;0.133621x0.0920732)
# DailyRate                    AxesSubplot(0.44569,0.787927;0.133621x0.0920732)
# Department                  AxesSubplot(0.606034,0.787927;0.133621x0.0920732)
# DistanceFromHome            AxesSubplot(0.766379,0.787927;0.133621x0.0920732)
# Education                      AxesSubplot(0.125,0.677439;0.133621x0.0920732)
# EducationField              AxesSubplot(0.285345,0.677439;0.133621x0.0920732)
# EnvironmentSatisfaction      AxesSubplot(0.44569,0.677439;0.133621x0.0920732)
# Gender                      AxesSubplot(0.606034,0.677439;0.133621x0.0920732)
# HourlyRate                  AxesSubplot(0.766379,0.677439;0.133621x0.0920732)
# JobInvolvement                 AxesSubplot(0.125,0.566951;0.133621x0.0920732)
# JobLevel                    AxesSubplot(0.285345,0.566951;0.133621x0.0920732)
# ...

# %% [markdown]
# #### check for imbalanced after removing outliers

# %%
sns.countplot(x="Attrition",data=df_x)
print(df_x['Attrition'].value_counts())
plt.show()
# Out:
# 0    1152
# 1     888
# Name: Attrition, dtype: int64

# %% [markdown]
# 1 to 0 ratio is 0.77 data is balanced

# %% [markdown]
# #### Splitting dataset

# %%
X=df_x.drop(columns=["Attrition"])
Y=df_x[["Attrition"]]

# %% [markdown]
# #### Running Algorithm

# %%
#importing necessary librairies 
#A=[] // stores test accuracy
#B=[] // stores cv_mean 
#C=[] // stores mean_squared_error
#D=[] // min diff between test accuracy and cv_score
#mae=[] // stores mean_absolute_error


from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
A=[]
B=[]
C=[]
D=[]
E=[]
mae=[]

# %%
#loop used to find the best random state
def max_aucroc_score(regr,X,Y):
    max_aucroc_score=0
    for r_state in range(0,100):
        x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = r_state, test_size=0.20,stratify=Y)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        aucroc_scr=(accuracy_score(y_test,y_pred))*100
        print("accuracy score corresponding to ",r_state," is ",aucroc_scr)
        if aucroc_scr>max_aucroc_score:
            max_aucroc_score=aucroc_scr
            final_r_state=r_state
    print("max accuracy score corresponding to ",final_r_state," is ",max_aucroc_score)
    return final_r_state

# %%
# used to get test accuracy, train accuracy, mse, mae,F1score,confusion matrix,classification report and auc score
def te_t(regr,x_train,x_test,y_train,y_test):
    regr.fit(x_train,y_train)
    y_tr=regr.predict(x_train)
    y_te=regr.predict(x_test)
    print(f"test accuracy is {round(accuracy_score(y_test,y_te)*100,1)}")
    A.append(round(accuracy_score(y_test,y_te)*100,1))
   
    print(f"train accuracy is {round(accuracy_score(y_train,y_tr)*100,1)}")
    C.append(mean_squared_error(y_test,y_te))
    mae.append(mean_absolute_error(y_test,y_te))
    
    
    cm = confusion_matrix(y_test, y_te)
    class_label = ["Yes", "No"]
    df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
    sns.heatmap(df_cm, annot=True, fmt='d')
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    print('\n')
    
    print("f1 score is : ",f1_score(y_test,y_te))
    E.append(f1_score(y_test,y_te))
    print('\n')
    
    print("classification report \n",classification_report(y_test,y_te))

# %%
# used to find the best cv_score
def score(regr,x_train,x_test,y_train,y_test):
    max_cv_mean=0
    min_dif=100
    r=0
    k=0
    y_tr=regr.predict(x_train)
    y_te=regr.predict(x_test)
    t_ac=round(accuracy_score(y_train,y_tr)*100,1)
    te_ac=round(accuracy_score(y_test,y_te)*100,1)
    for j in range(2,20):
        cv_score=cross_val_score(regr,X,Y,cv=j)
        cv_mean=cv_score.mean()*100
        d=np.abs(cv_mean-te_ac)
        print(f"At cv is {j} cv score is {round(cv_mean,2)}  \n test accuracy is {te_ac} \n")
        if cv_mean>max_cv_mean:
            max_cv_mean=cv_mean
            k=j
        if d<min_dif:
            min_dif=d
            r=j
    B.append(max_cv_mean) 
    print("min diff between test accuracy and cv score ",min_dif," at ", r," max cv ",max_cv_mean," at ",k)
    D.append(min_dif)

# %%
from sklearn.tree import DecisionTreeClassifier
reg=DecisionTreeClassifier()
R=max_aucroc_score(reg,X,Y)
# Out:
# accuracy score corresponding to  0  is  79.90196078431373
# accuracy score corresponding to  1  is  81.86274509803921
# accuracy score corresponding to  2  is  76.22549019607843
# accuracy score corresponding to  3  is  80.63725490196079
# accuracy score corresponding to  4  is  78.43137254901961
# accuracy score corresponding to  5  is  81.86274509803921
# accuracy score corresponding to  6  is  77.94117647058823
# accuracy score corresponding to  7  is  80.3921568627451
# accuracy score corresponding to  8  is  85.04901960784314
# accuracy score corresponding to  9  is  81.61764705882352
# accuracy score corresponding to  10  is  81.37254901960785
# accuracy score corresponding to  11  is  81.37254901960785
# accuracy score corresponding to  12  is  75.49019607843137
# accuracy score corresponding to  13  is  80.88235294117648
# accuracy score corresponding to  14  is  78.18627450980392
# accuracy score corresponding to  15  is  81.37254901960785
# ...

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(X,Y,random_state=R,test_size=0.2)
te_t(reg,x1_train,x1_test,y1_train,y1_test)
print('\n')
score(reg,x1_train,x1_test,y1_train,y1_test)
# Out:
# test accuracy is 81.9
# train accuracy is 100.0
# f1 score is :  0.8031914893617021
#
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       222
#            1       0.79      0.81      0.80       186
#
#     accuracy                           0.82       408
#    macro avg       0.82      0.82      0.82       408
# weighted avg       0.82      0.82      0.82       408
#
#
#
# At cv is 2 cv score is 79.61
#  test accuracy is 81.9
#
# At cv is 3 cv score is 79.31
#  test accuracy is 81.9
#
# At cv is 4 cv score is 78.63
#  test accuracy is 81.9
#
# At cv is 5 cv score is 79.36
#  test accuracy is 81.9
#
# At cv is 6 cv score is 78.87
#  test accuracy is 81.9
#
# At cv is 7 cv score is 80.3
#  test accuracy is 81.9
#
# At cv is 8 cv score is 80.54
#  test accuracy is 81.9
#
# At cv is 9 cv score is 82.06
#  test accuracy is 81.9
#
# At cv is 10 cv score is 80.83
#  test accuracy is 81.9
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf_c=RandomForestClassifier()
R=max_aucroc_score(rf_c,X,Y)
# Out:
# accuracy score corresponding to  0  is  87.99019607843137
# accuracy score corresponding to  1  is  91.17647058823529
# accuracy score corresponding to  2  is  88.97058823529412
# accuracy score corresponding to  3  is  92.64705882352942
# accuracy score corresponding to  4  is  88.23529411764706
# accuracy score corresponding to  5  is  91.17647058823529
# accuracy score corresponding to  6  is  89.2156862745098
# accuracy score corresponding to  7  is  90.68627450980392
# accuracy score corresponding to  8  is  92.8921568627451
# accuracy score corresponding to  9  is  91.42156862745098
# accuracy score corresponding to  10  is  90.19607843137256
# accuracy score corresponding to  11  is  91.42156862745098
# accuracy score corresponding to  12  is  89.70588235294117
# accuracy score corresponding to  13  is  91.91176470588235
# accuracy score corresponding to  14  is  91.42156862745098
# accuracy score corresponding to  15  is  90.19607843137256
# ...

# %%
x2_train,x2_test,y2_train,y2_test=train_test_split(X,Y,random_state=R,test_size=0.2)
te_t(rf_c,x2_train,x2_test,y2_train,y2_test)
print('\n')
score(rf_c,x2_train,x2_test,y2_train,y2_test)
# Out:
# test accuracy is 90.2
# train accuracy is 100.0
# f1 score is :  0.8757763975155279
#
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       242
#            1       0.90      0.85      0.88       166
#
#     accuracy                           0.90       408
#    macro avg       0.90      0.89      0.90       408
# weighted avg       0.90      0.90      0.90       408
#
#
#
# At cv is 2 cv score is 88.38
#  test accuracy is 90.2
#
# At cv is 3 cv score is 89.56
#  test accuracy is 90.2
#
# At cv is 4 cv score is 89.61
#  test accuracy is 90.2
#
# At cv is 5 cv score is 90.83
#  test accuracy is 90.2
#
# At cv is 6 cv score is 90.83
#  test accuracy is 90.2
#
# At cv is 7 cv score is 91.23
#  test accuracy is 90.2
#
# At cv is 8 cv score is 91.13
#  test accuracy is 90.2
#
# At cv is 9 cv score is 91.77
#  test accuracy is 90.2
#
# At cv is 10 cv score is 91.18
#  test accuracy is 90.2
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
kc=KNeighborsClassifier()
R=max_aucroc_score(kc,X,Y)
# Out:
# accuracy score corresponding to  0  is  79.16666666666666
# accuracy score corresponding to  1  is  82.1078431372549
# accuracy score corresponding to  2  is  81.86274509803921
# accuracy score corresponding to  3  is  80.88235294117648
# accuracy score corresponding to  4  is  80.88235294117648
# accuracy score corresponding to  5  is  82.84313725490196
# accuracy score corresponding to  6  is  76.7156862745098
# accuracy score corresponding to  7  is  83.08823529411765
# accuracy score corresponding to  8  is  80.63725490196079
# accuracy score corresponding to  9  is  82.1078431372549
# accuracy score corresponding to  10  is  83.33333333333334
# accuracy score corresponding to  11  is  79.65686274509804
# accuracy score corresponding to  12  is  79.41176470588235
# accuracy score corresponding to  13  is  78.43137254901961
# accuracy score corresponding to  14  is  81.12745098039215
# accuracy score corresponding to  15  is  80.14705882352942
# ...

# %%
x3_train,x3_test,y3_train,y3_test=train_test_split(X,Y,random_state=R,test_size=0.2)
te_t(kc,x3_train,x3_test,y3_train,y3_test)
print('\n')
score(kc,x3_train,x3_test,y3_train,y3_test)
# Out:
# test accuracy is 79.7
# train accuracy is 86.6
# f1 score is :  0.8065268065268066
#
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.98      0.66      0.79       232
#            1       0.68      0.98      0.81       176
#
#     accuracy                           0.80       408
#    macro avg       0.83      0.82      0.80       408
# weighted avg       0.85      0.80      0.79       408
#
#
#
# At cv is 2 cv score is 79.36
#  test accuracy is 79.7
#
# At cv is 3 cv score is 79.8
#  test accuracy is 79.7
#
# At cv is 4 cv score is 81.13
#  test accuracy is 79.7
#
# At cv is 5 cv score is 80.88
#  test accuracy is 79.7
#
# At cv is 6 cv score is 80.69
#  test accuracy is 79.7
#
# At cv is 7 cv score is 81.57
#  test accuracy is 79.7
#
# At cv is 8 cv score is 81.37
#  test accuracy is 79.7
#
# At cv is 9 cv score is 81.23
#  test accuracy is 79.7
#
# At cv is 10 cv score is 81.37
#  test accuracy is 79.7
#
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
grad_c=GradientBoostingClassifier()
R=max_aucroc_score(grad_c,X,Y)
# Out:
# accuracy score corresponding to  0  is  87.99019607843137
# accuracy score corresponding to  1  is  89.2156862745098
# accuracy score corresponding to  2  is  89.95098039215686
# accuracy score corresponding to  3  is  92.15686274509804
# accuracy score corresponding to  4  is  89.70588235294117
# accuracy score corresponding to  5  is  90.44117647058823
# accuracy score corresponding to  6  is  88.72549019607843
# accuracy score corresponding to  7  is  90.19607843137256
# accuracy score corresponding to  8  is  91.91176470588235
# accuracy score corresponding to  9  is  90.19607843137256
# accuracy score corresponding to  10  is  91.91176470588235
# accuracy score corresponding to  11  is  88.23529411764706
# accuracy score corresponding to  12  is  88.97058823529412
# accuracy score corresponding to  13  is  91.17647058823529
# accuracy score corresponding to  14  is  91.66666666666666
# accuracy score corresponding to  15  is  90.44117647058823
# ...

# %%
x4_train,x4_test,y4_train,y4_test=train_test_split(X,Y,random_state=R,test_size=0.2)
te_t(grad_c,x4_train,x4_test,y4_train,y4_test)
print('\n')
score(grad_c,x4_train,x4_test,y4_train,y4_test)
# Out:
# test accuracy is 88.7
# train accuracy is 96.3
# f1 score is :  0.8654970760233918
#
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.90       224
#            1       0.94      0.80      0.87       184
#
#     accuracy                           0.89       408
#    macro avg       0.90      0.88      0.88       408
# weighted avg       0.89      0.89      0.89       408
#
#
#
# At cv is 2 cv score is 86.18
#  test accuracy is 88.7
#
# At cv is 3 cv score is 85.59
#  test accuracy is 88.7
#
# At cv is 4 cv score is 86.47
#  test accuracy is 88.7
#
# At cv is 5 cv score is 88.33
#  test accuracy is 88.7
#
# At cv is 6 cv score is 88.73
#  test accuracy is 88.7
#
# At cv is 7 cv score is 88.74
#  test accuracy is 88.7
#
# At cv is 8 cv score is 89.17
#  test accuracy is 88.7
#
# At cv is 9 cv score is 89.52
#  test accuracy is 88.7
#
# At cv is 10 cv score is 89.66
#  test accuracy is 88.7
#
# ...

# %%
from sklearn.svm import SVC
svc=SVC()
R=max_aucroc_score(svc,X,Y)
# Out:
# accuracy score corresponding to  0  is  79.16666666666666
# accuracy score corresponding to  1  is  81.37254901960785
# accuracy score corresponding to  2  is  78.92156862745098
# accuracy score corresponding to  3  is  79.65686274509804
# accuracy score corresponding to  4  is  79.41176470588235
# accuracy score corresponding to  5  is  81.37254901960785
# accuracy score corresponding to  6  is  79.65686274509804
# accuracy score corresponding to  7  is  78.43137254901961
# accuracy score corresponding to  8  is  83.57843137254902
# accuracy score corresponding to  9  is  81.37254901960785
# accuracy score corresponding to  10  is  81.12745098039215
# accuracy score corresponding to  11  is  77.45098039215686
# accuracy score corresponding to  12  is  80.63725490196079
# accuracy score corresponding to  13  is  81.12745098039215
# accuracy score corresponding to  14  is  79.65686274509804
# accuracy score corresponding to  15  is  81.37254901960785
# ...

# %%
x5_train,x5_test,y5_train,y5_test=train_test_split(X,Y,random_state=R,test_size=0.2)
te_t(svc,x5_train,x5_test,y5_train,y5_test)
print('\n')
score(svc,x5_train,x5_test,y5_train,y5_test)
# Out:
# test accuracy is 81.4
# train accuracy is 81.4
# f1 score is :  0.7764705882352941
#
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       236
#            1       0.79      0.77      0.78       172
#
#     accuracy                           0.81       408
#    macro avg       0.81      0.81      0.81       408
# weighted avg       0.81      0.81      0.81       408
#
#
#
# At cv is 2 cv score is 76.32
#  test accuracy is 81.4
#
# At cv is 3 cv score is 78.19
#  test accuracy is 81.4
#
# At cv is 4 cv score is 78.97
#  test accuracy is 81.4
#
# At cv is 5 cv score is 79.9
#  test accuracy is 81.4
#
# At cv is 6 cv score is 80.64
#  test accuracy is 81.4
#
# At cv is 7 cv score is 80.06
#  test accuracy is 81.4
#
# At cv is 8 cv score is 80.34
#  test accuracy is 81.4
#
# At cv is 9 cv score is 80.74
#  test accuracy is 81.4
#
# At cv is 10 cv score is 80.59
#  test accuracy is 81.4
#
# ...

# %%
from sklearn.metrics import roc_curve,auc
area=[]

# %%
y_te=reg.predict(x1_test)
fpr1,tpr1,threshold1=roc_curve(y_te,y1_test)
roc_auc1= auc(fpr1, tpr1)
area.append(roc_auc1)
print("Area under the Decision Tree ROC curve : %f" % roc_auc1)
# Out:
# Area under the Decision Tree ROC curve : 0.817093

# %%
y_te=rf_c.predict(x2_test)
fpr2,tpr2,threshold2=roc_curve(y_te,y2_test)
roc_auc2= auc(fpr2, tpr2)
area.append(roc_auc2)
print("Area under the Random Forest ROC curve : %f" % roc_auc2)
# Out:
# Area under the Random Forest ROC curve : 0.902320

# %%
y_te=kc.predict(x3_test)
fpr3,tpr3,threshold3=roc_curve(y_te,y3_test)
roc_auc3= auc(fpr3, tpr3)
area.append(roc_auc3)
print("Area under the KNN ROC curve : %f" % roc_auc3)
# Out:
# Area under the KNN ROC curve : 0.832220

# %%
y_te=grad_c.predict(x4_test)
fpr4,tpr4,threshold4=roc_curve(y_te,y4_test)
roc_auc4= auc(fpr4, tpr4)
area.append(roc_auc4)
print("Area under the Grad boost ROC curve : %f" % roc_auc4)
# Out:
# Area under the Grad boost ROC curve : 0.896354

# %%
y_te=svc.predict(x5_test)
fpr5,tpr5,threshold5=roc_curve(y_te,y5_test)
roc_auc5= auc(fpr5, tpr5)
area.append(roc_auc5)
print("Area under the SVC ROC curve : %f" % roc_auc5)
# Out:
# Area under the SVC ROC curve : 0.809524

# %% [markdown]
# #### Creating Table to store datas

# %%
aa=['DT','RF','KNN','GRAD','SVC']

# %%
kk=pd.DataFrame({'test accuracy':A,'max_cv_score': B,'diff':D,'mse':C,'mae':mae,'F1 score':E,'roc_curve_area':area},index=aa)
kk.sort_values(by=['diff','test accuracy', 'mse', 'mae' ])
# Out:
#       test accuracy  max_cv_score      diff       mse       mae  F1 score  \
# GRAD           88.7     90.609237  0.025490  0.112745  0.112745  0.865497
# KNN            79.7     81.817867  0.103922  0.203431  0.203431  0.806527
# DT             81.9     82.647059  0.109804  0.181373  0.181373  0.803191
# RF             90.2     92.269161  0.592157  0.098039  0.098039  0.875776
# SVC            81.4     80.739759  0.660241  0.186275  0.186275  0.776471
#
#       roc_curve_area
# GRAD        0.896354
# KNN         0.832220
# DT          0.817093
# RF          0.902320
# SVC         0.809524

# %%
plt.figure(figsize = (20,15))

plt.plot(fpr1, tpr1, label = 'ROC curve for DT (area = %0.2f)' % roc_auc1)
plt.plot(fpr2, tpr2, label = 'ROC curve for RF (area = %0.2f)' % roc_auc2)
plt.plot(fpr3, tpr3, label = 'ROC curve for KNN (area = %0.2f)' % roc_auc3)
plt.plot(fpr4, tpr4, label = 'ROC curve for GRAD (area = %0.2f)' % roc_auc4)
plt.plot(fpr5, tpr5, label = 'ROC curve for svc (area = %0.2f)' % roc_auc5)

plt.plot([0, 1], [0, 1], [0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc = 'lower right', fontsize = 20)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Inference
# - Grad is the best model
#     - second highesr roc_curve
#     - second highest test accuracy
#     - second highest cv_score
#     - least differnce betwwen cv_score and test accuracy
#     - second highest F1 score
#     - second least error for mae and mse

# %% [markdown]
# #### hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
par={'loss':['log_loss', 'deviance', 'exponential'],
     'learning_rate':[1,10,0.1,0.08,0.5,0.05,0.01,0.09,0.4,0.6,0.8],
     'criterion':['friedman_mse','mse'],
     'n_estimators':[10,50,100,150,200,250,300,350,400],
     'max_features' : ['auto', 'sqrt', 'log2']
}

# %%
grid=GridSearchCV(grad_c,par,cv=2)
grid.fit(x4_train,y4_train)
grid.best_params_
# Out:
# {'criterion': 'mse',
#  'learning_rate': 0.09,
#  'loss': 'log_loss',
#  'max_features': 'log2',
#  'n_estimators': 150}

# %%
grad=GradientBoostingClassifier( criterion= 'mse', learning_rate= 0.09, loss= 'log_loss', max_features= 'log2', n_estimators= 150)
grad.fit(x4_train,y4_train)
y_te=grad.predict(x4_test)
aucroc_scr=(accuracy_score(y4_test,y_te))*100
print(aucroc_scr)
# Out:
# 88.72549019607843

# %%
cv_score=cross_val_score(grad,X,Y,cv=2)
cv_mean=cv_score.mean()*100
print(cv_mean)
# Out:
# 86.32352941176471

# %% [markdown]
# #### Storing model and loading it

# %%
import pickle

# %%
filename='hr.pkl'
pickle.dump(grad,open(filename,'wb'))

# %%
l_m=pickle.load(open('hr.pkl','rb'))
re=l_m.score(x4_test,y4_test)
print(re*100)
# Out:
# 88.72549019607843
